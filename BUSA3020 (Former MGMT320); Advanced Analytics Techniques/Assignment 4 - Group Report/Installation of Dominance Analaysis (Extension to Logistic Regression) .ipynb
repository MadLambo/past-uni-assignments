# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# !pip install -U dominance-analysis
# !pip install -U -i https://test.pypi.org/simple/ dominance-analysis==1.0.8
# Out:
# Requirement already up-to-date: dominance-analysis in d:\anaconda 3\lib\site-packages (1.1.6)
# ...

# %%
from dominance_analysis import Dominance_Datasets
from dominance_analysis import Dominance
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("German_Credit_-_99.99__Clean.csv")
df.head(5)
# Out:
#    Creditability  Account Balance  Duration of Credit (month)  \
# 0              1                1                           1
# 1              1                1                           0
# 2              1                2                           0
# 3              1                1                           0
# 4              1                1                           0
#
#    Payment Status of Previous Credit  Purpose  Credit Amount  \
# 0                                  4        2              0
# 1                                  4        1              2
# 2                                  2        6              0
# 3                                  4        1              1
# 4                                  4        1              1
#
#    Value Savings/Stocks  Length of current employment  Instalment per cent  \
# 0                     1                             2                    4
# ...

# %%
dominance_regression=Dominance(data=df,target='Creditability',objective=1)
# Out:
# Selecting 20 Best Predictors for the Model
# Selected Predictors :  ['Account Balance', 'Duration of Credit (month)', 'Payment Status of Previous Credit', 'Purpose', 'Credit Amount', 'Value Savings/Stocks', 'Length of current employment', 'Instalment per cent', 'Sex', 'Marital Status ', 'Guarantors', 'Most valuable available asset', 'Age (years)', 'Concurrent Credits', 'Type of apartment', 'No of Credits at this Bank', 'Occupation', 'No of dependents', 'Telephone', 'Foreign Worker']
#
# ********************  R-Squared of Complete Model :  ********************
# R Squared : 0.22467235854551226

# %%
dominance_regression.incremental_rsquare()
# Out:
# Selecting 20 Best Predictors for the Model
# Selected Predictors :  ['Account Balance', 'Duration of Credit (month)', 'Payment Status of Previous Credit', 'Purpose', 'Credit Amount', 'Value Savings/Stocks', 'Length of current employment', 'Instalment per cent', 'Sex', 'Marital Status ', 'Guarantors', 'Most valuable available asset', 'Age (years)', 'Concurrent Credits', 'Type of apartment', 'No of Credits at this Bank', 'Occupation', 'No of dependents', 'Telephone', 'Foreign Worker']
#
# Creating models for 1048575 possible combinations of 20 features :
#  20%|████████████████▌                                                                  | 4/20 [00:15<01:08,  4.27s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d074f3dc5c51> in <module>
# ----> 1 dominance_regression.incremental_rsquare()
#
# ...

# %%
dominance_regression.dominance_stats()

# %%
dominance_classification=Dominance(data=df,target='Creditability',objective=0,pseudo_r2="mcfadden")

# %%
incr_variable_rsquare=dominance_classification.incremental_rsquare()

# %%
dominance_classification.dominance_stats()
