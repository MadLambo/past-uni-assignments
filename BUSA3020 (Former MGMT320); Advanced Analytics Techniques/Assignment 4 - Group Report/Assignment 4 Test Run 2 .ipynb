# %% [markdown]
# #### Import Relevant Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn import metrics
from dominance_analysis import Dominance_Datasets
from dominance_analysis import Dominance
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #### Read the data

# %%
df = pd.read_csv("German_Credit_-_99.99__Clean.csv")
df.head(5)
# Out:
#    Creditability  Account Balance  Duration of Credit (month)  \
# 0              1                1                           1
# 1              1                1                           0
# 2              1                2                           0
# 3              1                1                           0
# 4              1                1                           0
#
#    Payment Status of Previous Credit  Purpose  Credit Amount  \
# 0                                  4        2              0
# 1                                  4        1              2
# 2                                  2        6              0
# 3                                  4        1              1
# 4                                  4        1              1
#
#    Value Savings/Stocks  Length of current employment  Instalment per cent  \
# 0                     1                             2                    4
# ...

# %% [markdown]
# #### Determine the % of training and testing data - 70% Training and 30% Testing

# %%
train, test = train_test_split(df, test_size=0.3, random_state=0)
print(train.shape)
print(test.shape)
# Out:
# (700, 22)
# (300, 22)

# %% [markdown]
# #### Extract the the training and testing dataset into a csv file for later (Domaince Analysis) purposes

# %%
train = train.to_csv('Train.csv', index = False)
test = test.to_csv('Test.csv', index = False)

# %% [markdown]
# #### Load the dataset

# %%
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")

# %% [markdown]
# #### Dominance Analysis
# - The dataset we are using is the training dataset
# - The objective is set to 0 - for classification purposes
# - The package (Dominance Analysis) will create a model (by using all the variables at first) with all the possible combinations and choose which variables are the best ones to use in this situation.

# %%
dominance_classification=Dominance(data=train,target='Creditability',objective=0,pseudo_r2="mcfadden")
# Out:
# Selecting 15 Best Predictors for the Model
# Selected Predictors :  ['Account Balance', 'Duration of Credit (month)', 'Payment Status of Previous Credit', 'Credit Amount', 'Value Savings/Stocks', 'Length of current employment', 'Instalment per cent', 'Sex', 'Marital Status ', 'Most valuable available asset', 'Age (years)', 'Concurrent Credits', 'No of Credits at this Bank', 'Telephone', 'Foreign Worker']
#
# ********************  Pseudo R-Squared of Complete Model :  ********************
#
# MacFadden's R-Squared : 0.19341703960124623

# %%
incr_variable_rsquare=dominance_classification.incremental_rsquare()
# Out:
# Selecting 15 Best Predictors for the Model
# Selected Predictors :  ['Account Balance', 'Duration of Credit (month)', 'Payment Status of Previous Credit', 'Credit Amount', 'Value Savings/Stocks', 'Length of current employment', 'Instalment per cent', 'Sex', 'Marital Status ', 'Most valuable available asset', 'Age (years)', 'Concurrent Credits', 'No of Credits at this Bank', 'Telephone', 'Foreign Worker']
#
# Creating models for 32767 possible combinations of 15 features :
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [03:10<00:00, 12.71s/it]
# #########################  Model Training Done!!!!!  #########################
#
# #########################  Calculating Variable Dominances  #########################
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [03:27<00:00, 14.80s/it]
# #########################  Variable Dominance Calculation Done!!!!!  #########################

# %%
dominance_classification.dominance_stats()
# Out:
#                                   Interactional Dominance  \
# Account Balance                                  0.058909
# Payment Status of Previous Credit              0.00869376
# Value Savings/Stocks                            0.0110829
# Duration of Credit (month)                       0.007883
# Most valuable available asset                  0.00971152
# Instalment per cent                              0.011408
# Length of current employment                   0.00622368
# Age (years)                                    0.00300829
# Concurrent Credits                             0.00453687
# Foreign Worker                                  0.0047582
# Sex                                           0.000907559
# Marital Status                                 0.00034951
# Credit Amount                                  0.00106091
# No of Credits at this Bank                    4.06756e-06
# Telephone                                     0.000514857
#
# ...

# %%
df.columns
df.drop(['Occupation','Type of apartment', 'Duration in Current address', 'No of dependents', 'Guarantors', 'Purpose'], axis = 1)
# Out:
#      Creditability  Account Balance  Duration of Credit (month)  \
# 0                1                1                           1
# 1                1                1                           0
# 2                1                2                           0
# 3                1                1                           0
# 4                1                1                           0
# ..             ...              ...                         ...
# 995              0                1                           2
# 996              0                1                           2
# 997              0                4                           2
# 998              0                2                           0
# 999              0                1                           3
#
#      Payment Status of Previous Credit  Credit Amount  Value Savings/Stocks  \
# 0                                    4              0                     1
# ...

# %%
y = df['Creditability']
x = df.drop(['Creditability'], axis = 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
logreg = linear_model.LogisticRegression()
logreg.fit(x_train, y_train)
# Out:
# D:\Anaconda 3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_lg = logreg.predict(x_test)
from sklearn.metrics import accuracy_score
print ("Accuracy score =", accuracy_score(y_test, y_pred_lg))

from sklearn.metrics import confusion_matrix 
print("Confusion Matrix = \n", confusion_matrix(y_test, y_pred_lg))
# Out:
# Accuracy score = 0.77
# Confusion Matrix =
#  [[ 47  53]
#  [ 16 184]]

# %%
print(metrics.classification_report(y_test, y_pred_lg, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.746     0.470     0.577       100
#            1      0.776     0.920     0.842       200
#
#     accuracy                          0.770       300
#    macro avg      0.761     0.695     0.709       300
# weighted avg      0.766     0.770     0.754       300

# %%
from sklearn.ensemble import RandomForestClassifier

randomforest = RandomForestClassifier(random_state=0)
randomforest.fit(x_train, y_train)
y_pred_rf = randomforest.predict(x_test)
acc_randomforest = round(accuracy_score(y_pred_rf, y_test) * 100, 2)
print(metrics.classification_report(y_test, y_pred_rf, digits=3))
# Out:
# D:\Anaconda 3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning:
#
# The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#               precision    recall  f1-score   support
#
#            0      0.687     0.460     0.551       100
#            1      0.768     0.895     0.827       200
#
#     accuracy                          0.750       300
#    macro avg      0.727     0.677     0.689       300
# weighted avg      0.741     0.750     0.735       300

# %%
# Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gaussian = GaussianNB()
gaussian.fit(x_train, y_train)
y_pred_nb = gaussian.predict(x_test)
acc_gaussian = round(accuracy_score(y_pred_nb, y_test) * 100, 2)
print(metrics.classification_report(y_test, y_pred_nb, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.586     0.650     0.616       100
#            1      0.815     0.770     0.792       200
#
#     accuracy                          0.730       300
#    macro avg      0.700     0.710     0.704       300
# weighted avg      0.738     0.730     0.733       300

# %%
credit_tree = DecisionTreeClassifier(random_state=0)
credit_tree .fit(x_train, y_train)

y_train_predict_dt = credit_tree.predict(x_train)
y_test_predict_dt = credit_tree.predict(x_test)

print("Decision Tree Train Accuracy:", accuracy_score(y_train_predict_dt, y_train))
print("Decision Tree Test Accuracy:", accuracy_score(y_test_predict_dt, y_test))
print(metrics.classification_report(y_test, y_test_predict_dt, digits=3))
# Out:
# Decision Tree Train Accuracy: 1.0
# Decision Tree Test Accuracy: 0.6866666666666666
#               precision    recall  f1-score   support
#
#            0      0.543     0.380     0.447       100
#            1      0.730     0.840     0.781       200
#
#     accuracy                          0.687       300
#    macro avg      0.637     0.610     0.614       300
# weighted avg      0.668     0.687     0.670       300

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred_knn = knn.predict(x_test)
acc_knn = round(accuracy_score(y_pred_knn, y_test) * 100, 2)
print(acc_knn)
print(metrics.classification_report(y_test, y_pred_knn, digits=3))
# Out:
# 74.33
#               precision    recall  f1-score   support
#
#            0      0.677     0.440     0.533       100
#            1      0.762     0.895     0.823       200
#
#     accuracy                          0.743       300
#    macro avg      0.719     0.667     0.678       300
# weighted avg      0.733     0.743     0.726       300
